# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Classifying-MNIST-Fashion-Clothing-Articles-Using-Convolutional-Neural-Networks" data-toc-modified-id="Classifying-MNIST-Fashion-Clothing-Articles-Using-Convolutional-Neural-Networks-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Classifying MNIST-Fashion Clothing Articles Using Convolutional Neural Networks</strong></a></span></li><li><span><a href="#Part-1---Setup" data-toc-modified-id="Part-1---Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Part 1 - Setup</a></span><ul class="toc-item"><li><span><a href="#Necessary-Installations" data-toc-modified-id="Necessary-Installations-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Necessary Installations</a></span></li><li><span><a href="#Library-Imports" data-toc-modified-id="Library-Imports-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Library Imports</a></span></li><li><span><a href="#Google-Drive-Connection" data-toc-modified-id="Google-Drive-Connection-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Google Drive Connection</a></span></li><li><span><a href="#Create-working-directory-for-this-run" data-toc-modified-id="Create-working-directory-for-this-run-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Create working directory for this run</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Change-into-main-directory" data-toc-modified-id="Change-into-main-directory-2.4.0.1"><span class="toc-item-num">2.4.0.1&nbsp;&nbsp;</span>Change into main directory</a></span></li><li><span><a href="#Generate-new-run-name-by-combining-random-word-with-the-current-date-and-time" data-toc-modified-id="Generate-new-run-name-by-combining-random-word-with-the-current-date-and-time-2.4.0.2"><span class="toc-item-num">2.4.0.2&nbsp;&nbsp;</span>Generate new run name by combining random word with the current date and time</a></span></li><li><span><a href="#Create-a-directory-for-this-run-and-set-it-as-the-working-directory" data-toc-modified-id="Create-a-directory-for-this-run-and-set-it-as-the-working-directory-2.4.0.3"><span class="toc-item-num">2.4.0.3&nbsp;&nbsp;</span>Create a directory for this run and set it as the working directory</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Part-2---Data-ingestion-and-preprocessing" data-toc-modified-id="Part-2---Data-ingestion-and-preprocessing-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Part 2 - Data ingestion and preprocessing</a></span><ul class="toc-item"><li><span><a href="#Read-in-data-and-split-into-subsets" data-toc-modified-id="Read-in-data-and-split-into-subsets-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Read in data and split into subsets</a></span></li><li><span><a href="#Reshape-and-normalize-X" data-toc-modified-id="Reshape-and-normalize-X-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Reshape and normalize X</a></span></li><li><span><a href="#One-hot-encoding-of-class-variables" data-toc-modified-id="One-hot-encoding-of-class-variables-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>One hot encoding of class variables</a></span></li><li><span><a href="#Set-Global-Variables" data-toc-modified-id="Set-Global-Variables-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Set Global Variables</a></span></li><li><span><a href="#Other-functions" data-toc-modified-id="Other-functions-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Other functions</a></span></li><li><span><a href="#Plot-some-images-to-see-what-the-data-looks-like" data-toc-modified-id="Plot-some-images-to-see-what-the-data-looks-like-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Plot some images to see what the data looks like</a></span></li><li><span><a href="#Display-8-images-of-a-specific-class-to-see-variation-(Sneakers)" data-toc-modified-id="Display-8-images-of-a-specific-class-to-see-variation-(Sneakers)-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Display 8 images of a specific class to see variation (Sneakers)</a></span></li></ul></li><li><span><a href="#Part-3---Baseline-Model" data-toc-modified-id="Part-3---Baseline-Model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Part 3 - Baseline Model</a></span><ul class="toc-item"><li><span><a href="#Build-Model" data-toc-modified-id="Build-Model-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Build Model</a></span></li><li><span><a href="#Compile-the-model" data-toc-modified-id="Compile-the-model-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Compile the model</a></span></li><li><span><a href="#Fit-the-model" data-toc-modified-id="Fit-the-model-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Fit the model</a></span></li><li><span><a href="#Plot-training-and-validation-accuracy-and-loss" data-toc-modified-id="Plot-training-and-validation-accuracy-and-loss-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Plot training and validation accuracy and loss</a></span></li><li><span><a href="#Evaluate-on-testing-data" data-toc-modified-id="Evaluate-on-testing-data-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Evaluate on testing data</a></span></li></ul></li><li><span><a href="#Part-4---Hyperparamter-Tuning" data-toc-modified-id="Part-4---Hyperparamter-Tuning-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Part 4 - Hyperparamter Tuning</a></span><ul class="toc-item"><li><span><a href="#Create-model-and-set-hyperparameters-to-tune" data-toc-modified-id="Create-model-and-set-hyperparameters-to-tune-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Create model and set hyperparameters to tune</a></span></li><li><span><a href="#Set-parameters-of-search-space" data-toc-modified-id="Set-parameters-of-search-space-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Set parameters of search space</a></span></li><li><span><a href="#Summary-of-tuner" data-toc-modified-id="Summary-of-tuner-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Summary of tuner</a></span></li><li><span><a href="#Search-for-best-hyperparameters" data-toc-modified-id="Search-for-best-hyperparameters-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Search for best hyperparameters</a></span></li><li><span><a href="#Choose-best-model" data-toc-modified-id="Choose-best-model-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Choose best model</a></span></li><li><span><a href="#Find-optimal-number-of-epochs." data-toc-modified-id="Find-optimal-number-of-epochs.-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Find optimal number of epochs.</a></span></li><li><span><a href="#Refit-one-more-time-on-best-number-epochs" data-toc-modified-id="Refit-one-more-time-on-best-number-epochs-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Refit one more time on best number epochs</a></span></li><li><span><a href="#Plot-training-and-validation-accuracy-and-loss" data-toc-modified-id="Plot-training-and-validation-accuracy-and-loss-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Plot training and validation accuracy and loss</a></span></li><li><span><a href="#Evaluate-on-testing-data" data-toc-modified-id="Evaluate-on-testing-data-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Evaluate on testing data</a></span></li></ul></li><li><span><a href="#Part-5---Analysis" data-toc-modified-id="Part-5---Analysis-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Part 5 - Analysis</a></span><ul class="toc-item"><li><span><a href="#Make-some-predictions-to-visualize-whats-happening" data-toc-modified-id="Make-some-predictions-to-visualize-whats-happening-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Make some predictions to visualize whats happening</a></span></li><li><span><a href="#Confusion-Matrix" data-toc-modified-id="Confusion-Matrix-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Confusion Matrix</a></span><ul class="toc-item"><li><span><a href="#Compute-prediction-accuracy" data-toc-modified-id="Compute-prediction-accuracy-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Compute prediction accuracy</a></span></li><li><span><a href="#Show-heatmapped-confusion-matrix" data-toc-modified-id="Show-heatmapped-confusion-matrix-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Show heatmapped confusion matrix</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # **Classifying MNIST-Fashion Clothing Articles Using Convolutional Neural Networks**
#
# **Group Members:**
# * Dino Anastasopoulos: 1900661
# * Philani Mpofu: 1848751
# * Chloë Smith: 1877342

# %% [markdown]
# # Part 1 - Setup

# %% [markdown]
# ## Necessary Installations

# %%
# !pip install keras-tuner --upgrade
# !pip install random-word
# Out:
# Requirement already up-to-date: keras-tuner in /usr/local/lib/python3.7/dist-packages (1.0.3)
# ...

# %% [markdown]
# ## Library Imports

# %%
#Standard/Basic Stuff
import cv2
import os

import numpy as np
import scipy as sp
import math
import imutils
import random
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import datetime
from datetime import datetime

from random_word import RandomWords

from skimage import io
from sklearn.model_selection import train_test_split
from sklearn.metrics import *


from google.colab import drive


#TensorFlow and Keras stuff
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Convolution2D, MaxPooling2D, BatchNormalization, Dropout, AveragePooling2D

# from keras.models import Sequential, Model
# from keras.layers import Dense, Flatten, Conv2D, Convolution2D, MaxPooling2D, BatchNormalization, Dropout, AveragePooling2D

from tensorflow.keras.optimizers import Adam, RMSprop

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import ResNet50

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

#Keras Tuner
import keras_tuner as kt
from keras_tuner import HyperModel
from keras_tuner.tuners import RandomSearch, Hyperband

print("All packages succesfully installed")
# Out:
# All packages succesfully installed

# %% [markdown]
# ## Google Drive Connection
# (This is necessary for working with Google Colab)

# %%
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Create working directory for this run
# The code below will create a new folder named by the current data and time. This will allow us to save all results, figures and models in a new directory for each run.

# %% [markdown]
# #### Change into main directory

# %%
cd /content/gdrive/MyDrive/MNIST_WORKING_DIRECTORY/
# Out:
# /content/gdrive/MyDrive/MNIST_WORKING_DIRECTORY

# %% [markdown]
# #### Generate new run name by combining random word with the current date and time

# %%
r = RandomWords()
random_word = r.get_random_word()
print(random_word)
# Out:
# unbulleted

# %%
current_date_time = datetime.now() # current date and time
date_time = current_date_time.strftime("%d-%m@%H:%M")
print(date_time)
# Out:
# 22-06@11:51

# %% [markdown]
# #### Create a directory for this run and set it as the working directory

# %%
run_name = random_word + "-" + date_time
print(run_name)
# Out:
# unbulleted-22-06@11:51

# %%
os.mkdir("Runs/" + run_name)

# %%
cd "Runs/$run_name"

# %% [markdown]
# # Part 2 - Data ingestion and preprocessing

# %% [markdown]
# ## Read in data and split into subsets
# *   Roughly 68% training, 17% validation and 15% testing data.

# %%
(trainX, trainY_original), (testX, testY_original) = keras.datasets.fashion_mnist.load_data()

trainX, valX, trainY_original, valY_original = train_test_split(trainX, trainY_original, test_size=0.2)

# %%
print("Train X Shape: ", trainX.shape)
print("Val X Shape: ", valX.shape)
print("Test X Shape: ", testX.shape)
# Out:
# Train X Shape:  (48000, 28, 28)
# Val X Shape:  (12000, 28, 28)
# Test X Shape:  (10000, 28, 28)

# %%
print("Original Train Y Shape: ", trainY_original.shape)
print("Original Val Y Shape: ", valY_original.shape)
print("Original Test Y Shape: ", testY_original.shape)
# Out:
# Original Train Y Shape:  (48000,)
# Original Val Y Shape:  (12000,)
# Original Test Y Shape:  (10000,)

# %% [markdown]
# ## Reshape and normalize X

# %%
trainX = trainX.reshape(-1, 28, 28, 1)
valX = valX.reshape(-1, 28, 28, 1)
testX = testX.reshape(-1, 28, 28, 1)


trainX = trainX /255.0
valX = valX /255.0
testX = testX /255.0

# %%
print("Train X Shape: ", trainX.shape)
print("Val X Shape: ", valX.shape)
print("Test X Shape: ", testX.shape)
# Out:
# Train X Shape:  (48000, 28, 28, 1)
# Val X Shape:  (12000, 28, 28, 1)
# Test X Shape:  (10000, 28, 28, 1)

# %% [markdown]
# ## One hot encoding of class variables

# %%
trainY = keras.utils.to_categorical(trainY_original, 10)
valY = keras.utils.to_categorical(valY_original, 10)
testY = keras.utils.to_categorical(testY_original, 10)

print("Encoded Train Y Shape: ", trainY.shape)
print("Encoded Val Y Shape: ", valY.shape)
print("Encoded Test Y Shape: ", testY.shape)
# Out:
# Encoded Train Y Shape:  (48000, 10)
# Encoded Val Y Shape:  (12000, 10)
# Encoded Test Y Shape:  (10000, 10)

# %% [markdown]
# ## Set Global Variables

# %%
class_labels = {0 : 'T-shirt/top',
            1 : 'Trouser',
            2 : 'Pullover',
            3 : 'Dress',
            4 : 'Coat',
            5 : 'Sandal',
            6 : 'Shirt',
            7 : 'Sneaker',
            8 : 'Bag',
            9 : 'Ankle boot'}

imgShape = [28,28,1]
numClasses = 10
classes = list(class_labels.values())

# %% [markdown]
# ## Other functions

# %%
def Plot_Training_Progress(history):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']
    epochs = range(len(acc))

    fig, axes = plt.subplots(1, 2, figsize=(25,10))
    
    #Plot Accuracy
    axes[0].plot(epochs, acc, 'b-', label='Training Accuracy')
    axes[0].plot(epochs, val_acc, 'g--', label='Validation Accuracy')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend(loc='best')

    #Plot Loss
    axes[1].plot(epochs, loss, 'b-', label='Training Loss')
    axes[1].plot(epochs, val_loss, 'g--', label='Validation Loss')
    axes[1].set_title('Training and Validation Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend(loc='best')

    return plt

# %% [markdown]
# ## Plot some images to see what the data looks like

# %%
plt.figure(figsize=(30,15))
j = 1
for i in np.random.randint(0,trainX.shape[0],18):
  plt.subplot(3,6,j); j+=1
  plt.imshow(trainX[i].reshape(28,28), cmap = 'gray')
  plt.axis('off')
  plt.title('Class {} - {}'.format(np.argmax(trainY[i]),class_labels[np.argmax(trainY[i])]))

plt.savefig('Class_Item_Examples.png', dpi=400)

# %% [markdown]
# ## Display 8 images of a specific class to see variation (Sneakers)

# %%
plt.figure(figsize=(20,10))
j = 1
num_found=1

while(num_found < 9):
  i = np.random.randint(0,45000)
  if(np.argmax(trainY[i]) == 7):
    plt.subplot(2,4,num_found); j+=1
    plt.imshow(trainX[i].reshape(28,28), cmap = 'gray')
    plt.axis('off')
    num_found+=1

plt.savefig('Sneaker_Examples.png', dpi=400)

# %% [markdown]
# # Part 3 - Baseline Model

# %% [markdown]
# ## Build Model

# %%
model = keras.Sequential()
model.add(Conv2D(filters=16,kernel_size=3,activation='relu',input_shape=imgShape))
model.add(Conv2D(filters=16,activation='relu',kernel_size=3))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(Conv2D(32,activation='relu',kernel_size=3))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128))
model.add(Dropout(0.2))
model.add(Dense(numClasses, activation='softmax'))

# %% [markdown]
# ## Compile the model

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
  loss='categorical_crossentropy',
  metrics=['accuracy']
)

# %%
keras.utils.plot_model(model, to_file='Baseline_Model_Architecture.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 26, 26, 16)        160
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 16)        2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 16)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 12, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 10, 10, 32)        4640
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 32)          9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 32)          0
# ...

# %% [markdown]
# ## Fit the model

# %%
Fashion_MNIST_Baseline_History = model.fit(trainX, trainY, epochs=20, validation_data=(valX, valY))
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.6684 - accuracy: 0.7509 - val_loss: 0.4155 - val_accuracy: 0.8513
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4510 - accuracy: 0.8355 - val_loss: 0.3377 - val_accuracy: 0.8764
# Epoch 3/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3957 - accuracy: 0.8553 - val_loss: 0.3254 - val_accuracy: 0.8826
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3708 - accuracy: 0.8643 - val_loss: 0.2987 - val_accuracy: 0.8916
# Epoch 5/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3529 - accuracy: 0.8718 - val_loss: 0.2781 - val_accuracy: 0.8976
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3416 - accuracy: 0.8745 - val_loss: 0.2792 - val_accuracy: 0.8974
# Epoch 7/20
# ...

# %% [markdown]
# ## Plot training and validation accuracy and loss

# %%
plt = Plot_Training_Progress(Fashion_MNIST_Baseline_History.history)   
plt.savefig('Baseline_Implementation_Plots.png', dpi=400)    
plt.show()

# %% [markdown]
# ## Evaluate on testing data

# %%
testLoss, testAccuracy = model.evaluate(testX,testY)

print("Testing Loss", testLoss)
print("Testing Accuracy", "{:.2%}" .format(testAccuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2862 - accuracy: 0.8976
# Testing Loss 0.28618142008781433
# Testing Accuracy 89.76%

# %% [markdown]
# # Part 4 - Hyperparamter Tuning

# %% [markdown]
# ## Create model and set hyperparameters to tune

# %%
class MNIST_Fashion_Hyper(HyperModel):
  def __init__(self, input_shape, num_classes):
    self.input_shape = input_shape
    self.num_classes = num_classes

  def build(self, hp):
    model = keras.Sequential()

    model.add(Conv2D(filters=hp.Choice('Conv_Filters_1',values=[16, 32, 64],default=16),activation='relu',kernel_size=3, input_shape=self.input_shape))
    model.add(Conv2D(filters=hp.Choice('Conv_Filters_2',values=[16, 32, 64],default=16), activation=hp.Choice('Conv_Activation_2',values=['relu', 'sigmoid'],default='relu'),kernel_size=3))
    model.add(MaxPooling2D(pool_size=2))
    model.add(Dropout(rate=hp.Float('Dropout_Rate_1',min_value=0.0,max_value=0.5,default=0.25,step=0.05)))
  
    model.add(Conv2D(filters=hp.Choice('Conv_Filters_3',values=[32, 64, 128],default=32), activation=hp.Choice('Conv_Activation_3',values=['relu', 'sigmoid'],default='relu'),kernel_size=3))
    model.add(Conv2D(filters=hp.Choice('Conv_Filters_4',values=[32, 64, 128],default=64), activation=hp.Choice('Conv_Activation_4',values=['relu', 'sigmoid'],default='relu'),kernel_size=3))
    model.add(AveragePooling2D(pool_size=2))
    model.add(Dropout(rate=hp.Float('Dropout_Rate_2',min_value=0.0,max_value=0.5,default=0.25,step=0.05)))

    model.add(Flatten())
    model.add(Dense(units=hp.Int('Last_Dense_NumUnits',min_value=16,max_value=128,step=16,default=64), activation='relu'))
    model.add(Dropout(rate=hp.Float('Dropout_Rate_3',min_value=0.0,max_value=0.5,default=0.25,step=0.05)))
    model.add(Dense(self.num_classes, activation='softmax'))

    model.compile(optimizer=keras.optimizers.Adam(hp.Float('Adam_Optim_LR',min_value=1e-4,max_value=1e-2,sampling='LOG',default=1e-3)),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print("MODEL SUCCESSFULLY CREATED")

    return model

# %%
hyper_model = MNIST_Fashion_Hyper(imgShape, numClasses)

# %% [markdown]
# ## Set parameters of search space
# i.e. Number of trials, epochs per trial, etc.

# %%
maxTrials = 20
execPerTrial = 2
numEpochSearch = 10
seedValue = 2

model_tuner = RandomSearch(
    hyper_model,
    objective='val_accuracy',
    seed=seedValue,
    max_trials=maxTrials,
    executions_per_trial=execPerTrial,
    project_name='MNIST_HyperTuned'
)
# Out:
# MODEL SUCCESSFULLY CREATED

# %% [markdown]
# ## Summary of tuner
# i.e. The hyperparameters that will be tuned

# %%
model_tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 12
# Conv_Filters_1 (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64], 'ordered': True}
# Conv_Filters_2 (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64], 'ordered': True}
# Conv_Activation_2 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid'], 'ordered': False}
# Dropout_Rate_1 (Float)
# {'default': 0.25, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.05, 'sampling': None}
# Conv_Filters_3 (Choice)
# {'default': 32, 'conditions': [], 'values': [32, 64, 128], 'ordered': True}
# Conv_Activation_3 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid'], 'ordered': False}
# Conv_Filters_4 (Choice)
# {'default': 64, 'conditions': [], 'values': [32, 64, 128], 'ordered': True}
# Conv_Activation_4 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid'], 'ordered': False}
# Dropout_Rate_2 (Float)
# ...

# %% [markdown]
# ## Search for best hyperparameters
# Note: This code block takes a while to run.

# %%
model_tuner.search(x=trainX, y=trainY, epochs=numEpochSearch, validation_data=(valX, valY))
# Out:
# Trial 20 Complete [00h 02m 24s]
# val_accuracy: 0.1014999970793724
#
# Best val_accuracy So Far: 0.9162916839122772
# Total elapsed time: 00h 50m 10s
# INFO:tensorflow:Oracle triggered exit

# %%
model_tuner.results_summary()
# Out:
# Results summary
# Results in ./MNIST_HyperTuned
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# Conv_Filters_1: 64
# Conv_Filters_2: 64
# Conv_Activation_2: relu
# Dropout_Rate_1: 0.25
# Conv_Filters_3: 128
# Conv_Activation_3: relu
# Conv_Filters_4: 32
# Conv_Activation_4: relu
# Dropout_Rate_2: 0.25
# Last_Dense_NumUnits: 80
# Dropout_Rate_3: 0.15000000000000002
# Adam_Optim_LR: 0.002312113349326375
# Score: 0.9162916839122772
# Trial summary
# Hyperparameters:
# Conv_Filters_1: 64
# Conv_Filters_2: 64
# Conv_Activation_2: relu
# Dropout_Rate_1: 0.25
# Conv_Filters_3: 32
# Conv_Activation_3: sigmoid
# Conv_Filters_4: 32
# Conv_Activation_4: relu
# Dropout_Rate_2: 0.4
# Last_Dense_NumUnits: 32
# Dropout_Rate_3: 0.2
# Adam_Optim_LR: 0.0007393219895594406
# Score: 0.9050416648387909
# Trial summary
# Hyperparameters:
# Conv_Filters_1: 32
# Conv_Filters_2: 16
# Conv_Activation_2: sigmoid
# ...

# %% [markdown]
# ## Choose best model

# %%
best_model = model_tuner.get_best_models()[0]
keras.utils.plot_model(best_model, to_file='HyperTuned_Model_Architecture.png', show_shapes=True, show_layer_names=True)
# Out:
# MODEL SUCCESSFULLY CREATED

# %%
testLoss, testAccuracy = best_model.evaluate(testX, testY)

print("Testing Loss before refitting", testLoss)
print("Testing Accuracy before refitting", "{:.2%}" .format(testAccuracy))

# %% [markdown]
# ## Find optimal number of epochs.

# %%
numEpochsToTrain = 20

best_model_history = best_model.fit(trainX, trainY, epochs=numEpochsToTrain, validation_data=(valX, valY),  batch_size=256)

val_acc_per_epoch = best_model_history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Optimal Number Epochs: %d' % (best_epoch))
# Out:
# Epoch 1/20
# 188/188 [==============================] - 4s 23ms/step - loss: 0.1178 - accuracy: 0.9564 - val_loss: 0.2318 - val_accuracy: 0.9314
# Epoch 2/20
# 188/188 [==============================] - 4s 22ms/step - loss: 0.1079 - accuracy: 0.9581 - val_loss: 0.2372 - val_accuracy: 0.9312
# Epoch 3/20
# 188/188 [==============================] - 4s 23ms/step - loss: 0.1023 - accuracy: 0.9611 - val_loss: 0.2340 - val_accuracy: 0.9302
# Epoch 4/20
# 188/188 [==============================] - 4s 23ms/step - loss: 0.1007 - accuracy: 0.9622 - val_loss: 0.2397 - val_accuracy: 0.9311
# Epoch 5/20
# 188/188 [==============================] - 4s 22ms/step - loss: 0.0997 - accuracy: 0.9615 - val_loss: 0.2374 - val_accuracy: 0.9310
# Epoch 6/20
# 188/188 [==============================] - 4s 21ms/step - loss: 0.1000 - accuracy: 0.9620 - val_loss: 0.2395 - val_accuracy: 0.9326
# Epoch 7/20
# ...

# %% [markdown]
# ## Refit one more time on best number epochs

# %%
Fashion_MNIST_Best_HyperParameters_History = best_hypermodel.fit(trainX, trainY, epochs=best_epoch, validation_data=(valX, valY), batch_size=256)
# Out:
# MODEL SUCCESSFULLY CREATED
# Epoch 1/6
# 188/188 [==============================] - 5s 22ms/step - loss: 0.2092 - accuracy: 0.9230 - val_loss: 0.2077 - val_accuracy: 0.9254
# Epoch 2/6
# 188/188 [==============================] - 4s 21ms/step - loss: 0.1944 - accuracy: 0.9268 - val_loss: 0.2065 - val_accuracy: 0.9258
# Epoch 3/6
# 188/188 [==============================] - 4s 21ms/step - loss: 0.1898 - accuracy: 0.9303 - val_loss: 0.2051 - val_accuracy: 0.9256
# Epoch 4/6
# 188/188 [==============================] - 4s 21ms/step - loss: 0.1855 - accuracy: 0.9301 - val_loss: 0.2000 - val_accuracy: 0.9274
# Epoch 5/6
# 188/188 [==============================] - 4s 21ms/step - loss: 0.1810 - accuracy: 0.9323 - val_loss: 0.1989 - val_accuracy: 0.9277
# Epoch 6/6
# 188/188 [==============================] - 4s 21ms/step - loss: 0.1762 - accuracy: 0.9352 - val_loss: 0.1997 - val_accuracy: 0.9291

# %% [markdown]
# ## Plot training and validation accuracy and loss

# %%
plt = Plot_Training_Progress(Fashion_MNIST_Best_HyperParameters_History.history)   
plt.savefig('Best_HyperParameters_Plots.png', dpi=400)    
plt.show()

# %% [markdown]
# ## Evaluate on testing data

# %%
testLoss, testAccuracy = best_hypermodel.evaluate(testX, testY)

print("Testing Loss", testLoss)
print("Testing Accuracy", "{:.2%}" .format(testAccuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2233 - accuracy: 0.9231
# Testing Loss 0.22327379882335663
# Testing Accuracy 92.31%

# %% [markdown]
# # Part 5 - Analysis

# %% [markdown]
# ## Make some predictions to visualize whats happening

# %%
n = 5
fig, axes = plt.subplots(1, n, figsize=(25,8))

for i in range(n):
    #Get random image
    randNum = random.randint(0,9999)
    random_image = testX[randNum]
    random_image_class = np.argmax(testY[randNum])
    
    #Make prediction
    prediction = best_hypermodel.predict(random_image.reshape(-1,28,28,1))
    prediction_probability = np.amax(prediction)
    prediction_idx = np.argmax(prediction)

    title = "Actual class = {}\nPredicted class = {}\nPrediction probability = {:.2%}" .format(class_labels[random_image_class], class_labels[prediction_idx], prediction_probability)

    # Print image
    axes[i].imshow(random_image.reshape(28,28), cmap='gray')
    if(prediction_idx == random_image_class):
      axes[i].set_title(title, color='g')
    else:
      axes[i].set_title(title, color='r')
    axes[i].axis('off')

plt.savefig('Prediction_Visualizations.png', dpi=400)    
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# ### Compute prediction accuracy

# %%
y_pred, y_true = [], []
for i in range(9000):
  image = testX[i]
  image_class = np.argmax(testY[i])

  prediction = best_hypermodel.predict(image.reshape(-1,28,28,1))
  prediction_idx = np.argmax(prediction)

  y_pred.append(prediction_idx)
  y_true.append(image_class)

# %% [markdown]
# ### Show heatmapped confusion matrix

# %%
fig, ax = plt.subplots(figsize=(15,15))
conf_matrix = confusion_matrix(y_true, y_pred, labels=np.arange(10))
conf_matrix = conf_matrix/np.sum(conf_matrix, axis=1)
sns.heatmap(conf_matrix, annot=True, fmt=".2%", square=True, cbar=False, 
            cmap=plt.cm.cividis, xticklabels=classes, yticklabels=classes,
            ax=ax)
ax.set_ylabel('Actual')
ax.set_xlabel('Predicted')
ax.set_title('Confusion Matrix')

plt.savefig('Confusion_Matrix.png', dpi=400)    

plt.show()
